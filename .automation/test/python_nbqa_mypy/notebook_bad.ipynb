# %%
# This notebook has type errors that should be caught by nbqa-mypy

def add_numbers(x: int, y: int) -> int:
    return x + y

# Type error: passing string to function expecting int
result = add_numbers("hello", 5)

# Type error: incompatible return type
def get_value() -> int:
    return "not an int"

# Type error: undefined variable
print(undefined_var)
